# %% [markdown]
# # Image Classification ML Assignment
#
# The goal of this assignment is to learn fundamentals of machine learning and image analysis. You will analyze images from Happy Whale, an organization that tracks whales globally, and modify a classifier for these images.
#
# Part 1: Walk through (Due Feb 27)
# - In class, we will walk through the provided code
# - This script has several functions that are written for you. For part 1, please do NOT modify any code unless it specifies to change it.
# - Answer the questions as you go through the code
#
# Part 2: Make modifications (Due Feb 27)
# - Change model parameters or other model aspects at least 3 times
# - Describe what happened when you made these changes
#
# Part 3: Create a team, get inspired and try a new approach to your model (Due March 6)
# - Have a group meeting and record your meeting with audio or video (you can record with zoom!)
#     - Start by discussing part 2 of the assignment:
#         - What approaches you each took to change the ML model in part 2
#         - What are similarities and differences between your approaches
#         - What types of changes improved model performance
#         - What types of changes made model performance worse
#         - Based on the whole group's work, what would y'all want to do next in terms of model optimization?
#     - Next, look at code and approaches from the [Happy Whales competition leaderboard](https://www.kaggle.com/competitions/happy-whale-and-dolphin/leaderboard).
#         - Is there any strategy that someone used that you could implement?
#             - Ex: learning rate value, # epochs, transformation strategy, or more complex changes to the models
#         - Are there strategies that you are interested in learning about?
#     - Lastly, make a plan for 1 more round of model optimization
#         - Assign each member something to attempt for training the model. Use your cumulative experience to decide the most important things to test.
#         - Group members can make as small as changing the value for a parameter or as big as changing the model.
# - Have each member complete their test
# - Share results with each other
# - Write a 1-3 paragraph summary on your group's attempts and recommendations moving forward
# - For Part 3: Turn in the audio/video recording of the group meeting, each member's code (uploaded to their original git repo), and the team's 1-3 paragraph summary over canvas.

# %% [markdown]
# ### Your choices on data
# You can chose between 3 datasets for this assignment. This jupyter notebook is set up using the Species dataset. If you change the dataset, you will need to change the number of classes parameter for the model.
# - Species = you will classify images by species (gray, killer, beluga, humpback, false killer, and common dolphin)
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
# - Species_all = you will classify images by species (minke, gray, killer, beluga, humpback, false killer, and bottlenose and common dolphin). There are a high number of images for bottlenose dolphins and minke whales which leads to this dataset being quite large. Due to the size of the dataset, it has a longer training time than the "Species" dataset.
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species_all
#   - Num classes: 8
# - Individuals = you will classify images by individuals. This is a much more challenging classification task because you have different individuals from different species. However, this was the original goal of the Happy Whale competition, so try challenging yourself to this important task!
#   - File path: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/individuals
#   - Num classes: 110
#
# You are NOT graded by the success of your model, so you are free to train the model on whichever dataset is more interesting to you. However, **everyone on your team for part 3 should be using the same dataset**.

# %% [markdown]
# ### Part 1

# %%
## Importing packages - Please DO NOT alter this box ##
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
from torch.utils.data.sampler import WeightedRandomSampler
torch.manual_seed(0)

from captum.attr import IntegratedGradients
from captum.attr import DeepLift
from captum.attr import NoiseTunnel
from captum.attr import visualization as viz

import torchvision
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter()

import os
import imageio
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from tqdm import tqdm
from scipy.ndimage import binary_erosion
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

import wandb #comment this out if you are not using weights and biases
import random #comment this out if you are not using weights and biases

# Set device to cuda if it's available otherwise default to "cpu"
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ### Loading in the dataset
#
# By default, this will load in the species dataset, this is the smallest dataset (i.e., it will be relatively fast to train) and has a simple goal (i.e., you will be able to create an accurate model). If you want a challenge, I highly encourage you to try the Species_all (a dataset with 2 additional species) or the individual dataset (a dataset where whales are characterized by individual rather than species).

# %%
images = "/projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species"

# %%
# We must turn our images into tensors, resize, and normalize them 
# We can also add additional transformations to images 
transform = transforms.Compose([transforms.ToTensor(), 
                                #We will start with a model called Resnet18 that is optimized for 224x224 images
                                #It is set to a very SMALL size initially so the model will train fast in class
                                transforms.Resize([32,32]),
                                transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences)
                               ])
all_images = datasets.ImageFolder(images, transform)
print(all_images)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# <font color='magenta'>What is the purpose(s) of transforming image data? (2 pts)

# %% [markdown]
# Transforming image data helps to further train the model, prevent overfitting, and/or fit the model requirements.

# %% [markdown]
# <font color='green'>The below code completes the image transformations as coded in the above box.

# %%
all_images = datasets.ImageFolder(images, transform )
print(len(all_images))
print(all_images)
# Out:
# 2794
# Dataset ImageFolder
#     Number of datapoints: 2794
#     Root location: /projects/bgmp/shared/Bi625/ML_Assignment/Datasets/Whale_species/species
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Resize(size=[32, 32], interpolation=bilinear, max_size=None, antialias=True)
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Our classification labels will be converted to indices, we can determine which indices is which label using the below code

# %%
print(all_images.class_to_idx)
# Out:
# {'beluga': 0, 'common_dolphin': 1, 'false_killer_whale': 2, 'fin_whale': 3, 'gray_whale': 4, 'humpback_whale': 5}

# %% [markdown]
# <font color='green'>The below function is used to randomly select dataset images to evaluate how the transformations altered the images.

# %%
def show_random_dataset_image(dataset):
    idx = np.random.randint(0, len(dataset))    # take a random sample
    img, mask = dataset[idx]                    # get the image and the nuclei masks
    f, axarr = plt.subplots(1, 2)               # make two plots on one figure
    axarr[0].imshow(img[0], cmap="viridis")                     # show the image, cmap is the color map that the image is being shown in
    #axarr[1].imshow(mask[0])                    # show the masks
    _ = [ax.axis('off') for ax in axarr]        # remove the axes
    print('Image size is %s' % {img[0].shape})
    print(img.shape)
    plt.show()

# %%
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([32, 32])}
# torch.Size([3, 32, 32])

# %% [markdown]
# <font color='magenta'>What is the difference between image size and torch image size? (2 pts)

# %% [markdown]
# Image size refers to the original image dimensions. Torch size I believe is how it is coded in as a tensor

# %% [markdown]
# <font color='magenta'>Add a new transformation to the training data. After your first run of this model during class time, resize the image to 224x224 pixels. (2 pts)

# %%
## ADD YOUR TRANSFORMATION HERE
transform = transforms.Compose([
            transforms.Resize([224,224]), # Resize the image as our model is optimized for 224x224 pixels
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]) # Normalize the data, these are the values that ResNet suggests based on their training data (natural scences))

all_images = datasets.ImageFolder(images, transform )
show_random_dataset_image(all_images)
# Out:
# Image size is {torch.Size([224, 224])}
# torch.Size([3, 224, 224])

# %% [markdown]
# <font color='magenta'>How did your transformation impact the images? (1 pt)

# %% [markdown]
# The image appears WAY more detailed and high dimensional

# %% [markdown]
# ### Creating datasets used in training and testing
#
# After loading in the data, we separate the data into training, validation, and testing datasets. The training data is inputted into the model during the training phase, and the model's predictions from this data is used to modulate the weights of the model. The validation data is used while the model trains, but the model is in a evaluation rather than training mode. The validation data gives us a real time view on how accurately the model is predicting our labels. The testing data is used after the model has completed training and tells us how successful our model will be with a novel dataset.
#
# Once creating these 3 datasets, we prepare dataloaders which are used to load the images into our models. These images are loaded in batches into the model (a parameter called batch size). Because our dataset is imbalanced, we use a weighted random sampler to select images for our batches in the dataloader. Therefore to create our dataloader, we start by creating a function to get weights, calculating weights, initiating our weighted random sampler, and then creating our dataloaders.

# %% [markdown]
# <font color='green'>The below code eastablishes the data split between training, validation, and testing.

# %%
train_size = int(0.7 * len(all_images))
val_size = int(0.15 * len(all_images))
test_size = len(all_images) - (train_size + val_size)
print(train_size, val_size, test_size)
assert train_size + val_size + test_size == len(all_images)
# Out:
# 1955 419 420

# %%
train_set, val_set, test_set = torch.utils.data.random_split(all_images, [train_size, val_size, test_size])

# %% [markdown]
# <font color='green'>The below function is used to get weights for the image classes.

# %%
def _get_weights(subset,full_dataset):
    ys = np.array([y for _, y in subset])
    counts = np.bincount(ys)
    label_weights = 1.0 / counts
    weights = label_weights[ys]

    print("Number of images per class:")
    for c, n, w in zip(full_dataset.classes, counts, label_weights):
        print(f"\t{c}:\tn={n}\tweight={w}")
        
    return weights

# %%
train_weights = _get_weights(train_set,all_images)
train_sampler = WeightedRandomSampler(train_weights, len(train_weights))
# Out:
# Number of images per class:
# 	beluga:	n=473	weight=0.0021141649048625794
# 	common_dolphin:	n=46	weight=0.021739130434782608
# 	false_killer_whale:	n=684	weight=0.0014619883040935672
# 	fin_whale:	n=126	weight=0.007936507936507936
# 	gray_whale:	n=53	weight=0.018867924528301886
# 	humpback_whale:	n=573	weight=0.0017452006980802793

# %% [markdown]
# <font color='magenta'>What is the impact of the class weight on how data is loaded into the model? What does it mean if a class has a low vs high weight? (2 pts)

# %% [markdown]
# <details>
#   <summary>Hint</summary>
#
# Check out this resource: https://towardsdatascience.com/demystifying-pytorchs-weightedrandomsampler-by-example-a68aceccb452

# %% [markdown]
# I don't think it impacts how the data is loaded, only changes how the model is penalized for misclassifying the classes.

# %%
train_loader = DataLoader(train_set, batch_size=48, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=48, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=48, drop_last=True, shuffle=True)

# %% [markdown]
# ### Picking hyperparameters
#
# We can set a few hyperparameters that we decide and can tune. These include:
#
# - Learning rate = how much to update our model's parameters at each batch/epoch
# - batch size = the number of data samples to pass through the network before updating it
#     - If you change the batchsize below, make sure you ALSO change it in the commands above for the DataLoader
# - Number of epochs = # of times to iterate over the dataset in model training

# %%
learning_rate=1e-3
batchsize=48
epochs=5

# %% [markdown]
# <font color='magenta'>How would model training be impacted if we decreased our learning rate? What about if we increased it? (2 pts)

# %% [markdown]
# Decreasing the learning rate would probably slow down the model, while increasing it could speed it up initially, but might impact overall stabilitly.

# %% [markdown]
# ### Training our model
#
# For part 1, we are going to use the model ResNet18. This is a published model for imaging data. Resnet18 is built from 4 residual blocks with two convolutional layers (Conv2d). Each convolutional layer is followed by a batch normalization step (BatchNorm2D) and a ReLU activation layer (ReLU). There is also a shortcut connection which adds input to output and allows the network to learn residual mapping.
#
# I provided the complete code for the ResNet18 model. In the future, if you want to use resnet18, you can load it simply by running `resnet18_model = torchvision.models.resnet18(weights = False, progress  = True, num_classes=XXX)`. We will look at the full code for the model so you can see how this model was created.

# %% [markdown]
# <font color='green'>The below code builds the residual blocks that ResNet18 uses in the model.

# %%
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    # Initializing method for the basic block (It's OOP!)
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

# %% [markdown]
# <font color='green'>The below code builds and initializes the ResNet18 model.

# %%
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)
print(model)
# Out:
# ResNet18(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %% [markdown]
# <font color='green'>The below code eastablishes the loss function and optimizer used in training the model.

# %%
#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %% [markdown]
# <font color='green'>The below functions are used to train, evaluate, and test the Machine Learning model.

# %%
 wandb.login()
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/amdo/.netrc.
# wandb: Currently logged in as: amdo (BGMP_HappyWhale) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="Amandaaaaa-HappyWhale-SpeciesDataset-hyperparameters", ### Update with your name!
    config={"learning rate":0.001,
        "architecture": "CNN",
        "dataset": "Species",
        "epochs":5}
)

num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0
    batch=0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/amdo/HappyWhaleClassifier/wandb/run-20260302_175222-6i2iljtj</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/6i2iljtj' target="_blank">Amandaaaaa-HappyWhale-SpeciesDataset-hyperparameters</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/6i2iljtj' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/6i2iljtj</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 12.50%
# Epoch [1/5] | Batch #2 | Batch Accuracy 13.54%
# Epoch [1/5] | Batch #3 | Batch Accuracy 15.97%
# Epoch [1/5] | Batch #4 | Batch Accuracy 22.92%
# Epoch [1/5] | Batch #5 | Batch Accuracy 26.67%

# %% [markdown]
# #### For our class training, run the below model and consider the success of the model training.
#
# <font color='magenta'>What is your starting accuracy and final accuracy? What happened to the model to change the accuracy from epoch 1 to 5? (2 pts)

# %% [raw]
# Starting accuracy: Epoch [1/5] | Batch #1 | Batch Accuracy 8.33%
# Ending: Epoch [5/5] Train Loss: 0.7403 | Train Acc: 72.81% | Val Acc: 65.36% | Val Loss: 0.83%

# %% [markdown]
# Epoch [1/5] | Batch #1 | Batch Accuracy 8.33%

# %%
plt.plot(range(num_epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(num_epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()

# %% [markdown]
# <font color='green'>After running the model and calculating the overall accuracy, we can examine the data via a confusion matrix which highlights the accuracy by class.

# %%
# predict the test dataset
def predict(model, dataset):
    dataset_prediction = []
    dataset_groundtruth = []
    model = model
    with torch.no_grad():
        for x, y_true in dataset:
            inp = x[None]
            y_pred = model(inp)
            dataset_prediction.append(y_pred.argmax().cpu().numpy())
            dataset_groundtruth.append(y_true)
    
    return np.array(dataset_prediction), np.array(dataset_groundtruth)
            
    # create seaborn heatmap with required labels
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels)
    ax.set_title(title)

# Plot confusion matrix 
# orginally from Runqi Yang; 
# see https://gist.github.com/hitvoice/36cf44689065ca9b927431546381a3f7
def cm_analysis(y_true, y_pred, title, figsize=(10,10)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args: 
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale']
    cm = confusion_matrix(y_true, y_pred)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
                              
    x_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for x-axis
    y_axis_labels = ['Beluga','Common dolphin', 'False killer whale', 'Fin whale', 'Gray whale','Humpback whale'] # labels for y-axis
    ax=sns.heatmap(cm, annot=annot, fmt='', vmax=30, xticklabels=x_axis_labels, yticklabels=y_axis_labels, cmap = "viridis")
    ax.set_title(title)

## This plot only contains the test set of data
## The test set of data has not been seen by the model yet
y_pred, y_true = predict(model, test_set)

print(y_true)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# [2 2 2 5 2 0 5 0 5 5 5 2 0 2 5 0 2 5 2 5 2 5 2 2 5 0 5 5 2 1 2 0 5 2 2 5 0
#  0 0 5 5 2 3 5 2 3 0 0 5 0 0 2 2 2 2 2 2 2 0 0 4 4 0 5 0 1 5 5 2 3 2 1 2 2
#  2 5 0 2 0 0 0 2 2 2 5 0 5 2 2 2 0 5 2 5 0 5 5 5 0 5 5 2 0 2 0 5 2 2 2 2 2
#  3 5 0 5 5 0 2 2 2 5 2 2 2 2 5 5 5 0 2 5 5 2 5 5 2 3 5 3 2 2 0 5 3 0 5 2 5
#  5 2 0 2 2 2 5 5 5 5 2 2 2 0 1 5 0 0 0 0 2 2 3 0 2 0 2 2 2 2 4 2 2 2 4 2 3
#  5 2 2 2 5 0 2 1 2 2 5 0 2 4 0 4 5 5 2 5 0 2 2 2 5 2 0 0 5 0 2 5 0 5 3 2 5
#  0 2 1 2 2 2 2 5 2 2 5 2 5 3 5 3 0 5 5 2 0 2 0 2 3 5 5 5 2 0 2 5 2 2 5 5 2
#  5 2 0 5 2 2 3 2 5 5 2 2 1 5 0 1 2 5 2 2 2 1 2 5 2 1 2 0 0 2 2 2 2 2 5 2 0
#  2 2 3 2 2 2 2 5 2 0 0 2 2 2 4 3 2 2 0 2 2 5 2 5 0 0 0 0 5 2 2 2 5 5 2 2 2
#  5 1 5 0 2 2 0 5 4 5 5 5 2 2 0 5 5 5 2 2 2 2 1 2 2 2 0 5 2 0 3 2 2 2 1 2 0
#  2 5 3 1 0 1 2 2 5 2 2 0 0 5 0 5 2 0 0 0 0 2 5 0 4 5 2 0 5 2 2 0 0 3 0 0 0
#  2 0 0 5 2 1 0 0 0 2 5 0 3]
# /tmp/ipykernel_3330518/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# ### What features did the model use to make decisions?
#
# Based on the confusion matrices and validation loss, it is clear that the model is learning. To determine the features that are involved in decision making, there are a few possible approaches. One options is shown below, integrated gradients.

# %% [markdown]
# #### Understanding feature importance using Integrated Gradients
#
# <font color='green'>Integrated gradients is an attribution method. Attribution methods score the input data based on the prediction that the model makes using scores for each feature. The gradient is the signal that tells the network how much to increase or decrease a certain weight in the network during backpropogation. These gradients are overlaid onto the images to showcase the regions on the images that influence the weights.
#
# Run the below code.

# %%
def visualize_ig(idx, 
                 _train_dataset=train_set, 
                 _test_dataset=test_set):
        
    # Get corresponding input and target tensors:
    input_tensor = _test_dataset[idx][0].unsqueeze(0)
    input_tensor.requires_grad = True
    target = _test_dataset[idx][1]
    
    # We will use the IntegratedGradients algorithm:
    algorithm = IntegratedGradients(model)
    
    # First we clear the gradients from the model:
    model.zero_grad()
    
    # Run attribution:
    attr_ig, delta = algorithm.attribute(input_tensor,
                                          target=target,
                                          baselines=input_tensor * 0,
                                          return_convergence_delta=True
                                        )
    
    # Integrated Gradients:
    attr_ig = np.transpose(attr_ig[0].cpu().detach().numpy(), (1, 2, 0))
    
    # Original image:
    original_image = np.transpose((_test_dataset[idx][0].detach().numpy() * 0.5) + 0.5, (1, 2, 0))
    
    print("Annotated whale species", test_true[idx])
    plt.imshow(original_image)
    
    
    print("Predicted whale species", test_pred[idx])


    # This visualises the attribution of labels to 
    viz.visualize_image_attr(attr_ig, 
                             original_image, 
                             method="blended_heat_map",
                             sign="all",
                             show_colorbar=True, 
                             title="Overlayed Integrated Gradients")

test_pred, test_true = predict(model, test_set)

visualize_ig(0)
visualize_ig(8)
visualize_ig(20)
visualize_ig(32)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 44
#      36     # This visualises the attribution of labels to
#      37     viz.visualize_image_attr(attr_ig,
#      38                              original_image,
#      39                              method="blended_heat_map",
#      40                              sign="all",
#      41                              show_colorbar=True,
#      42                              title="Overlayed Integrated Gradients")
# ---> 44 test_pred, test_true = predict(model, test_set)
#      46 visualize_ig(0)
#      47 visualize_ig(8)
#
# Cell In[24], line 9, in predict(model, dataset)
#       7 for x, y_true in dataset:
#       8     inp = x[None]
# ----> 9     y_pred = model(inp)
#      10     dataset_prediction.append(y_pred.argmax().cpu().numpy())
#      11     dataset_groundtruth.append(y_true)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[19], line 42, in ResNet18.forward(self, x)
#      40 out = self.relu(out)
#      41 # Our 4 building blocks
# ---> 42 out = self.layer1(out)
#      43 out = self.layer2(out)
#      44 out = self.layer3(out)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[18], line 26, in BasicBlock.forward(self, x)
#      24 def forward(self, x):
#      25     ## Conv1: convolution layer, batch normalization, ReLU activation
# ---> 26     out = self.conv1(x)
#      27     out = self.bn1(out)
#      28     out = self.relu(out)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File /projects/bgmp/shared/Bi625/ML_Assignment/Conda_Envs/HumpbackClassifierEnv/lib/python3.13/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %% [markdown]
# <font color='magenta'>Does the integrated gradient show what types of features the model used to classify the images? Do you notice any potential problems? (2 pts)

# %% [markdown]
# It looks like it is training on the water features and is looking for breaks in the water patterns. This could be an issue if there are other things that are not water or emerging from the water.

# %% [markdown]
# ## Part 2
#
# Now that you have a sense for how to train a machine learning model, your task is to improve the success of our classification model.
#
# **In three separate training events, make one (or more) modifications to the model training process, re-train the model, and report out your changes and whether they increased model accuracy. Why did you chose your particular change (curiousity, hypothesis, ect.)? Do you have ideas why your modifications were/were not successful?**
#
# Types of changes that you can make include:
# - [Using the pre-trained weights for ResNet18 (transfer learning)](https://docs.pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html)
# - Changing hyperparameters (learning rate, batch size)
# - [Changing transformation approach](https://docs.pytorch.org/vision/0.11/auto_examples/plot_transforms.html#sphx-glr-auto-examples-plot-transforms-py)
# - [Changing the optimizer](https://docs.pytorch.org/docs/stable/optim.html)
# - [Changing the model to a different pre-made model architecture](https://docs.pytorch.org/vision/main/models.html)
# - Modifying the ResNet18 model
# - Coming up with a whole new model!
#
# If you decide to change any lines of code that are not in the below box, please add them to the box (DO NOT MODIFY ANY CODE ABOVE THIS MARKDOWN BOX - IT MAY BREAK PART 1).
#
# If your changes are ambitious, the code may take hours to run. If this is the case, please consider turning this notebook into a python script and running it via sBATCH.
#
# **Please note, you will NOT be graded by the success of your classifiers! It is okay if you are unable to improve the accuracy of the classifier**

# %% [markdown]
# #### Your Model 1 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# I am starting by adjusting the learning rate: new LR = 3e-4; this was decreased in order to see if changing the step rate of the weight updates can improve performance.

# %%
batchsize = 48
learning_rate=3e-4
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of filters/channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="amandaaaa-HappyWhale-SpeciesDataset-hyperparameters_mod1", ##update this with your name
    config={"learning rate":.01, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 3, "batch_size":48}  # possibly update
) 



plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/amdo/HappyWhaleClassifier/wandb/run-20260302_192748-zdutmd4o</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/zdutmd4o' target="_blank">amandaaaa-HappyWhale-SpeciesDataset-hyperparameters_mod1</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/zdutmd4o' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/zdutmd4o</a>
# /tmp/ipykernel_3330518/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %%
print("epochs =", epochs)
print("len(train_losses) =", len(train_losses))
print("len(val_acc_list) =", len(val_acc_list))
print("first val acc =", val_acc_list[0] if len(val_acc_list)>0 else None)
print("last  val acc =", val_acc_list[-1] if len(val_acc_list)>0 else None)
# Out:
# epochs = 5
# len(train_losses) = 5
# len(val_acc_list) = 5
# first val acc = 48.4375
# last  val acc = 69.27083333333333

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# The model ran so fast in comparison to the original one that I feel like I did something wrong, but the accuracy did improve so maybe yes? Maybe no?

# %% [markdown]
# #### Your Model 2 (10pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# Adding image weights from resnet18

# %%
batchsize = 32
learning_rate=3e-3
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
import torchvision.models as models

model = models.resnet18(weights="IMAGENET1K_V1")

# Replace final classification layer for 6 whale species
model.fc = nn.Linear(model.fc.in_features, 6)

model = model.to(device)
#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="amandaaa-HappyWhale-SpeciesDataset-hyperparameters_mod2", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 3, "batch_size":32}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">amandaaaa-HappyWhale-SpeciesDataset-hyperparameters_mod1</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/zdutmd4o' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/zdutmd4o</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260302_192748-zdutmd4o/logs</code>
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/amdo/HappyWhaleClassifier/wandb/run-20260302_192956-borv6urb</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/borv6urb' target="_blank">amandaaa-HappyWhale-SpeciesDataset-hyperparameters_mod2</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/borv6urb' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/borv6urb</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 6.25%
# Epoch [1/5] | Batch #2 | Batch Accuracy 29.69%
# Epoch [1/5] | Batch #3 | Batch Accuracy 38.54%
# Epoch [1/5] | Batch #4 | Batch Accuracy 38.28%
# Epoch [1/5] | Batch #5 | Batch Accuracy 43.12%
# Epoch [1/5] | Batch #6 | Batch Accuracy 43.75%
# Epoch [1/5] | Batch #7 | Batch Accuracy 42.86%
# Epoch [1/5] | Batch #8 | Batch Accuracy 42.97%
# Epoch [1/5] | Batch #9 | Batch Accuracy 43.75%
# Epoch [1/5] | Batch #10 | Batch Accuracy 41.25%
# Epoch [1/5] | Batch #11 | Batch Accuracy 42.05%
# Epoch [1/5] | Batch #12 | Batch Accuracy 41.41%
# Epoch [1/5] | Batch #13 | Batch Accuracy 42.31%
# Epoch [1/5] | Batch #14 | Batch Accuracy 41.74%
# Epoch [1/5] | Batch #15 | Batch Accuracy 42.29%
# Epoch [1/5] | Batch #16 | Batch Accuracy 42.19%
# Epoch [1/5] | Batch #17 | Batch Accuracy 41.73%
# Epoch [1/5] | Batch #18 | Batch Accuracy 41.15%
# Epoch [1/5] | Batch #19 | Batch Accuracy 42.43%
# Epoch [1/5] | Batch #20 | Batch Accuracy 42.19%
# Epoch [1/5] | Batch #21 | Batch Accuracy 43.30%
# Epoch [1/5] | Batch #22 | Batch Accuracy 43.18%
# Epoch [1/5] | Batch #23 | Batch Accuracy 44.43%
# Epoch [1/5] | Batch #24 | Batch Accuracy 44.66%
# Epoch [1/5] | Batch #25 | Batch Accuracy 45.12%
# Epoch [1/5] | Batch #26 | Batch Accuracy 45.31%
# Epoch [1/5] | Batch #27 | Batch Accuracy 45.60%
# Epoch [1/5] | Batch #28 | Batch Accuracy 45.31%
# Epoch [1/5] | Batch #29 | Batch Accuracy 45.58%
# Epoch [1/5] | Batch #30 | Batch Accuracy 45.73%
# Epoch [1/5] | Batch #31 | Batch Accuracy 46.07%
# Epoch [1/5] | Batch #32 | Batch Accuracy 46.68%
# Epoch [1/5] | Batch #33 | Batch Accuracy 46.97%
# Epoch [1/5] | Batch #34 | Batch Accuracy 47.33%
# Epoch [1/5] | Batch #35 | Batch Accuracy 48.21%
# Epoch [1/5] | Batch #36 | Batch Accuracy 48.61%
# Epoch [1/5] | Batch #37 | Batch Accuracy 48.99%
# Epoch [1/5] | Batch #38 | Batch Accuracy 49.92%
# Epoch [1/5] | Batch #39 | Batch Accuracy 50.16%
# Epoch [1/5] | Batch #40 | Batch Accuracy 50.62%
# Epoch [1/5] | Batch #41 | Batch Accuracy 50.84%
# Epoch [1/5] | Batch #42 | Batch Accuracy 51.19%
# Epoch [1/5] | Batch #43 | Batch Accuracy 51.38%
# Epoch [1/5] | Batch #44 | Batch Accuracy 51.85%
# Epoch [1/5] | Batch #45 | Batch Accuracy 51.74%
# Epoch [1/5] | Batch #46 | Batch Accuracy 52.17%
# Epoch [1/5] | Batch #47 | Batch Accuracy 52.86%
# Epoch [1/5] | Batch #48 | Batch Accuracy 52.93%
# Epoch [1/5] | Batch #49 | Batch Accuracy 53.19%
# Epoch [1/5] | Batch #50 | Batch Accuracy 53.69%
# Epoch [1/5] | Batch #51 | Batch Accuracy 53.92%
# Epoch [1/5] | Batch #52 | Batch Accuracy 53.97%
# Epoch [1/5] | Batch #53 | Batch Accuracy 54.25%
# Epoch [1/5] | Batch #54 | Batch Accuracy 54.69%
# Epoch [1/5] | Batch #55 | Batch Accuracy 54.89%
# Epoch [1/5] | Batch #56 | Batch Accuracy 55.13%
# Epoch [1/5] | Batch #57 | Batch Accuracy 55.32%
# Epoch [1/5] | Batch #58 | Batch Accuracy 55.66%
# Epoch [1/5] | Batch #59 | Batch Accuracy 56.20%
# Epoch [1/5] | Batch #60 | Batch Accuracy 56.56%
# Epoch [1/5] | Batch #61 | Batch Accuracy 56.76%
# Epoch [1/5] Train Loss: 1.2276 | Train Acc: 56.76% | Val Acc: 54.57% | Val Loss: 1.50%
# Epoch [2/5] | Batch #62 | Batch Accuracy 59.38%
# Epoch [2/5] | Batch #63 | Batch Accuracy 64.06%
# Epoch [2/5] | Batch #64 | Batch Accuracy 68.75%
# Epoch [2/5] | Batch #65 | Batch Accuracy 65.62%
# Epoch [2/5] | Batch #66 | Batch Accuracy 65.00%
# Epoch [2/5] | Batch #67 | Batch Accuracy 67.71%
# Epoch [2/5] | Batch #68 | Batch Accuracy 68.75%
# Epoch [2/5] | Batch #69 | Batch Accuracy 70.70%
# Epoch [2/5] | Batch #70 | Batch Accuracy 72.92%
# Epoch [2/5] | Batch #71 | Batch Accuracy 72.81%
# Epoch [2/5] | Batch #72 | Batch Accuracy 72.73%
# Epoch [2/5] | Batch #73 | Batch Accuracy 72.66%
# Epoch [2/5] | Batch #74 | Batch Accuracy 70.91%
# Epoch [2/5] | Batch #75 | Batch Accuracy 70.76%
# Epoch [2/5] | Batch #76 | Batch Accuracy 71.46%
# Epoch [2/5] | Batch #77 | Batch Accuracy 71.68%
# Epoch [2/5] | Batch #78 | Batch Accuracy 71.88%
# Epoch [2/5] | Batch #79 | Batch Accuracy 71.18%
# Epoch [2/5] | Batch #80 | Batch Accuracy 71.55%
# Epoch [2/5] | Batch #81 | Batch Accuracy 71.72%
# Epoch [2/5] | Batch #82 | Batch Accuracy 72.02%
# Epoch [2/5] | Batch #83 | Batch Accuracy 72.16%
# Epoch [2/5] | Batch #84 | Batch Accuracy 72.42%
# Epoch [2/5] | Batch #85 | Batch Accuracy 72.01%
# Epoch [2/5] | Batch #86 | Batch Accuracy 72.25%
# Epoch [2/5] | Batch #87 | Batch Accuracy 72.36%
# Epoch [2/5] | Batch #88 | Batch Accuracy 72.11%
# Epoch [2/5] | Batch #89 | Batch Accuracy 72.21%
# Epoch [2/5] | Batch #90 | Batch Accuracy 72.20%
# Epoch [2/5] | Batch #91 | Batch Accuracy 72.29%
# Epoch [2/5] | Batch #92 | Batch Accuracy 72.08%
# Epoch [2/5] | Batch #93 | Batch Accuracy 71.97%
# Epoch [2/5] | Batch #94 | Batch Accuracy 71.88%
# Epoch [2/5] | Batch #95 | Batch Accuracy 71.88%
# Epoch [2/5] | Batch #96 | Batch Accuracy 71.96%
# Epoch [2/5] | Batch #97 | Batch Accuracy 71.53%
# Epoch [2/5] | Batch #98 | Batch Accuracy 71.28%
# Epoch [2/5] | Batch #99 | Batch Accuracy 71.13%
# Epoch [2/5] | Batch #100 | Batch Accuracy 71.15%
# Epoch [2/5] | Batch #101 | Batch Accuracy 71.25%
# Epoch [2/5] | Batch #102 | Batch Accuracy 70.73%
# Epoch [2/5] | Batch #103 | Batch Accuracy 70.91%
# Epoch [2/5] | Batch #104 | Batch Accuracy 70.64%
# Epoch [2/5] | Batch #105 | Batch Accuracy 70.45%
# Epoch [2/5] | Batch #106 | Batch Accuracy 70.49%
# Epoch [2/5] | Batch #107 | Batch Accuracy 70.31%
# Epoch [2/5] | Batch #108 | Batch Accuracy 70.35%
# Epoch [2/5] | Batch #109 | Batch Accuracy 70.05%
# Epoch [2/5] | Batch #110 | Batch Accuracy 70.15%
# Epoch [2/5] | Batch #111 | Batch Accuracy 70.19%
# Epoch [2/5] | Batch #112 | Batch Accuracy 69.73%
# Epoch [2/5] | Batch #113 | Batch Accuracy 70.13%
# Epoch [2/5] | Batch #114 | Batch Accuracy 70.22%
# Epoch [2/5] | Batch #115 | Batch Accuracy 70.31%
# Epoch [2/5] | Batch #116 | Batch Accuracy 70.23%
# Epoch [2/5] | Batch #117 | Batch Accuracy 70.37%
# Epoch [2/5] | Batch #118 | Batch Accuracy 70.39%
# Epoch [2/5] | Batch #119 | Batch Accuracy 70.37%
# Epoch [2/5] | Batch #120 | Batch Accuracy 70.50%
# Epoch [2/5] | Batch #121 | Batch Accuracy 70.68%
# Epoch [2/5] | Batch #122 | Batch Accuracy 70.65%
# Epoch [2/5] Train Loss: 0.8045 | Train Acc: 70.65% | Val Acc: 70.43% | Val Loss: 0.77%
# Epoch [3/5] | Batch #123 | Batch Accuracy 78.12%
# Epoch [3/5] | Batch #124 | Batch Accuracy 75.00%
# Epoch [3/5] | Batch #125 | Batch Accuracy 77.08%
# Epoch [3/5] | Batch #126 | Batch Accuracy 78.91%
# Epoch [3/5] | Batch #127 | Batch Accuracy 80.62%
# Epoch [3/5] | Batch #128 | Batch Accuracy 79.69%
# Epoch [3/5] | Batch #129 | Batch Accuracy 78.57%
# Epoch [3/5] | Batch #130 | Batch Accuracy 78.91%
# Epoch [3/5] | Batch #131 | Batch Accuracy 78.12%
# Epoch [3/5] | Batch #132 | Batch Accuracy 78.75%
# Epoch [3/5] | Batch #133 | Batch Accuracy 78.98%
# Epoch [3/5] | Batch #134 | Batch Accuracy 79.43%
# Epoch [3/5] | Batch #135 | Batch Accuracy 79.09%
# Epoch [3/5] | Batch #136 | Batch Accuracy 79.02%
# Epoch [3/5] | Batch #137 | Batch Accuracy 79.17%
# Epoch [3/5] | Batch #138 | Batch Accuracy 77.73%
# Epoch [3/5] | Batch #139 | Batch Accuracy 77.57%
# Epoch [3/5] | Batch #140 | Batch Accuracy 77.78%
# Epoch [3/5] | Batch #141 | Batch Accuracy 76.15%
# Epoch [3/5] | Batch #142 | Batch Accuracy 76.72%
# Epoch [3/5] | Batch #143 | Batch Accuracy 77.23%
# Epoch [3/5] | Batch #144 | Batch Accuracy 77.13%
# Epoch [3/5] | Batch #145 | Batch Accuracy 76.90%
# Epoch [3/5] | Batch #146 | Batch Accuracy 76.30%
# Epoch [3/5] | Batch #147 | Batch Accuracy 75.88%
# Epoch [3/5] | Batch #148 | Batch Accuracy 75.48%
# Epoch [3/5] | Batch #149 | Batch Accuracy 75.12%
# Epoch [3/5] | Batch #150 | Batch Accuracy 75.33%
# Epoch [3/5] | Batch #151 | Batch Accuracy 75.32%
# Epoch [3/5] | Batch #152 | Batch Accuracy 75.31%
# Epoch [3/5] | Batch #153 | Batch Accuracy 74.80%
# Epoch [3/5] | Batch #154 | Batch Accuracy 74.71%
# Epoch [3/5] | Batch #155 | Batch Accuracy 74.81%
# Epoch [3/5] | Batch #156 | Batch Accuracy 74.72%
# Epoch [3/5] | Batch #157 | Batch Accuracy 75.00%
# Epoch [3/5] | Batch #158 | Batch Accuracy 75.17%
# Epoch [3/5] | Batch #159 | Batch Accuracy 75.34%
# Epoch [3/5] | Batch #160 | Batch Accuracy 75.25%
# Epoch [3/5] | Batch #161 | Batch Accuracy 75.16%
# Epoch [3/5] | Batch #162 | Batch Accuracy 75.23%
# Epoch [3/5] | Batch #163 | Batch Accuracy 75.38%
# Epoch [3/5] | Batch #164 | Batch Accuracy 75.52%
# Epoch [3/5] | Batch #165 | Batch Accuracy 75.65%
# Epoch [3/5] | Batch #166 | Batch Accuracy 75.71%
# Epoch [3/5] | Batch #167 | Batch Accuracy 75.83%
# Epoch [3/5] | Batch #168 | Batch Accuracy 75.68%
# Epoch [3/5] | Batch #169 | Batch Accuracy 75.60%
# Epoch [3/5] | Batch #170 | Batch Accuracy 75.59%
# Epoch [3/5] | Batch #171 | Batch Accuracy 75.70%
# Epoch [3/5] | Batch #172 | Batch Accuracy 75.75%
# Epoch [3/5] | Batch #173 | Batch Accuracy 75.92%
# Epoch [3/5] | Batch #174 | Batch Accuracy 75.90%
# Epoch [3/5] | Batch #175 | Batch Accuracy 75.94%
# Epoch [3/5] | Batch #176 | Batch Accuracy 76.04%
# Epoch [3/5] | Batch #177 | Batch Accuracy 76.19%
# Epoch [3/5] | Batch #178 | Batch Accuracy 76.45%
# Epoch [3/5] | Batch #179 | Batch Accuracy 76.54%
# Epoch [3/5] | Batch #180 | Batch Accuracy 76.72%
# Epoch [3/5] | Batch #181 | Batch Accuracy 76.75%
# Epoch [3/5] | Batch #182 | Batch Accuracy 76.61%
# Epoch [3/5] | Batch #183 | Batch Accuracy 76.64%
# Epoch [3/5] Train Loss: 0.6686 | Train Acc: 76.64% | Val Acc: 60.82% | Val Loss: 1.18%
# Epoch [4/5] | Batch #184 | Batch Accuracy 81.25%
# Epoch [4/5] | Batch #185 | Batch Accuracy 81.25%
# Epoch [4/5] | Batch #186 | Batch Accuracy 83.33%
# Epoch [4/5] | Batch #187 | Batch Accuracy 79.69%
# Epoch [4/5] | Batch #188 | Batch Accuracy 78.75%
# Epoch [4/5] | Batch #189 | Batch Accuracy 78.65%
# Epoch [4/5] | Batch #190 | Batch Accuracy 78.57%
# Epoch [4/5] | Batch #191 | Batch Accuracy 79.30%
# Epoch [4/5] | Batch #192 | Batch Accuracy 79.51%
# Epoch [4/5] | Batch #193 | Batch Accuracy 78.75%
# Epoch [4/5] | Batch #194 | Batch Accuracy 79.55%
# Epoch [4/5] | Batch #195 | Batch Accuracy 79.95%
# Epoch [4/5] | Batch #196 | Batch Accuracy 79.33%
# Epoch [4/5] | Batch #197 | Batch Accuracy 79.91%
# Epoch [4/5] | Batch #198 | Batch Accuracy 78.96%
# Epoch [4/5] | Batch #199 | Batch Accuracy 77.93%
# Epoch [4/5] | Batch #200 | Batch Accuracy 77.21%
# Epoch [4/5] | Batch #201 | Batch Accuracy 77.26%
# Epoch [4/5] | Batch #202 | Batch Accuracy 77.47%
# Epoch [4/5] | Batch #203 | Batch Accuracy 77.97%
# Epoch [4/5] | Batch #204 | Batch Accuracy 77.38%
# Epoch [4/5] | Batch #205 | Batch Accuracy 76.99%
# Epoch [4/5] | Batch #206 | Batch Accuracy 76.90%
# Epoch [4/5] | Batch #207 | Batch Accuracy 76.95%
# Epoch [4/5] | Batch #208 | Batch Accuracy 77.25%
# Epoch [4/5] | Batch #209 | Batch Accuracy 77.40%
# Epoch [4/5] | Batch #210 | Batch Accuracy 76.97%
# Epoch [4/5] | Batch #211 | Batch Accuracy 76.90%
# Epoch [4/5] | Batch #212 | Batch Accuracy 77.37%
# Epoch [4/5] | Batch #213 | Batch Accuracy 77.71%
# Epoch [4/5] | Batch #214 | Batch Accuracy 77.72%
# Epoch [4/5] | Batch #215 | Batch Accuracy 77.64%
# Epoch [4/5] | Batch #216 | Batch Accuracy 77.65%
# Epoch [4/5] | Batch #217 | Batch Accuracy 77.76%
# Epoch [4/5] | Batch #218 | Batch Accuracy 77.68%
# Epoch [4/5] | Batch #219 | Batch Accuracy 77.69%
# Epoch [4/5] | Batch #220 | Batch Accuracy 77.79%
# Epoch [4/5] | Batch #221 | Batch Accuracy 77.96%
# Epoch [4/5] | Batch #222 | Batch Accuracy 78.45%
# Epoch [4/5] | Batch #223 | Batch Accuracy 78.52%
# Epoch [4/5] | Batch #224 | Batch Accuracy 78.35%
# Epoch [4/5] | Batch #225 | Batch Accuracy 78.57%
# Epoch [4/5] | Batch #226 | Batch Accuracy 78.56%
# Epoch [4/5] | Batch #227 | Batch Accuracy 78.62%
# Epoch [4/5] | Batch #228 | Batch Accuracy 78.61%
# Epoch [4/5] | Batch #229 | Batch Accuracy 78.80%
# Epoch [4/5] | Batch #230 | Batch Accuracy 79.06%
# Epoch [4/5] | Batch #231 | Batch Accuracy 79.17%
# Epoch [4/5] | Batch #232 | Batch Accuracy 78.95%
# Epoch [4/5] | Batch #233 | Batch Accuracy 79.06%
# Epoch [4/5] | Batch #234 | Batch Accuracy 78.98%
# Epoch [4/5] | Batch #235 | Batch Accuracy 79.15%
# Epoch [4/5] | Batch #236 | Batch Accuracy 79.30%
# Epoch [4/5] | Batch #237 | Batch Accuracy 79.40%
# Epoch [4/5] | Batch #238 | Batch Accuracy 79.55%
# Epoch [4/5] | Batch #239 | Batch Accuracy 79.58%
# Epoch [4/5] | Batch #240 | Batch Accuracy 79.66%
# Epoch [4/5] | Batch #241 | Batch Accuracy 79.63%
# Epoch [4/5] | Batch #242 | Batch Accuracy 79.71%
# Epoch [4/5] | Batch #243 | Batch Accuracy 79.69%
# Epoch [4/5] | Batch #244 | Batch Accuracy 79.66%
# Epoch [4/5] Train Loss: 0.5719 | Train Acc: 79.66% | Val Acc: 71.63% | Val Loss: 0.70%
# Epoch [5/5] | Batch #245 | Batch Accuracy 84.38%
# Epoch [5/5] | Batch #246 | Batch Accuracy 85.94%
# Epoch [5/5] | Batch #247 | Batch Accuracy 87.50%
# Epoch [5/5] | Batch #248 | Batch Accuracy 88.28%
# Epoch [5/5] | Batch #249 | Batch Accuracy 86.88%
# Epoch [5/5] | Batch #250 | Batch Accuracy 86.46%
# Epoch [5/5] | Batch #251 | Batch Accuracy 86.16%
# Epoch [5/5] | Batch #252 | Batch Accuracy 86.72%
# Epoch [5/5] | Batch #253 | Batch Accuracy 86.11%
# Epoch [5/5] | Batch #254 | Batch Accuracy 86.56%
# Epoch [5/5] | Batch #255 | Batch Accuracy 84.94%
# Epoch [5/5] | Batch #256 | Batch Accuracy 84.90%
# Epoch [5/5] | Batch #257 | Batch Accuracy 85.10%
# Epoch [5/5] | Batch #258 | Batch Accuracy 84.82%
# Epoch [5/5] | Batch #259 | Batch Accuracy 84.17%
# Epoch [5/5] | Batch #260 | Batch Accuracy 84.38%
# Epoch [5/5] | Batch #261 | Batch Accuracy 83.27%
# Epoch [5/5] | Batch #262 | Batch Accuracy 83.33%
# Epoch [5/5] | Batch #263 | Batch Accuracy 83.06%
# Epoch [5/5] | Batch #264 | Batch Accuracy 82.03%
# Epoch [5/5] | Batch #265 | Batch Accuracy 82.59%
# Epoch [5/5] | Batch #266 | Batch Accuracy 82.95%
# Epoch [5/5] | Batch #267 | Batch Accuracy 83.02%
# Epoch [5/5] | Batch #268 | Batch Accuracy 83.20%
# Epoch [5/5] | Batch #269 | Batch Accuracy 82.88%
# Epoch [5/5] | Batch #270 | Batch Accuracy 82.69%
# Epoch [5/5] | Batch #271 | Batch Accuracy 82.87%
# Epoch [5/5] | Batch #272 | Batch Accuracy 82.70%
# Epoch [5/5] | Batch #273 | Batch Accuracy 83.08%
# Epoch [5/5] | Batch #274 | Batch Accuracy 83.23%
# Epoch [5/5] | Batch #275 | Batch Accuracy 83.06%
# Epoch [5/5] | Batch #276 | Batch Accuracy 83.30%
# Epoch [5/5] | Batch #277 | Batch Accuracy 83.24%
# Epoch [5/5] | Batch #278 | Batch Accuracy 83.18%
# Epoch [5/5] | Batch #279 | Batch Accuracy 83.39%
# Epoch [5/5] | Batch #280 | Batch Accuracy 83.25%
# Epoch [5/5] | Batch #281 | Batch Accuracy 82.69%
# Epoch [5/5] | Batch #282 | Batch Accuracy 82.73%
# Epoch [5/5] | Batch #283 | Batch Accuracy 82.61%
# Epoch [5/5] | Batch #284 | Batch Accuracy 82.73%
# Epoch [5/5] | Batch #285 | Batch Accuracy 82.39%
# Epoch [5/5] | Batch #286 | Batch Accuracy 82.29%
# Epoch [5/5] | Batch #287 | Batch Accuracy 82.63%
# Epoch [5/5] | Batch #288 | Batch Accuracy 82.81%
# Epoch [5/5] | Batch #289 | Batch Accuracy 82.92%
# Epoch [5/5] | Batch #290 | Batch Accuracy 83.15%
# Epoch [5/5] | Batch #291 | Batch Accuracy 83.38%
# Epoch [5/5] | Batch #292 | Batch Accuracy 83.40%
# Epoch [5/5] | Batch #293 | Batch Accuracy 83.23%
# Epoch [5/5] | Batch #294 | Batch Accuracy 83.19%
# Epoch [5/5] | Batch #295 | Batch Accuracy 83.39%
# Epoch [5/5] | Batch #296 | Batch Accuracy 83.11%
# Epoch [5/5] | Batch #297 | Batch Accuracy 83.20%
# Epoch [5/5] | Batch #298 | Batch Accuracy 83.16%
# Epoch [5/5] | Batch #299 | Batch Accuracy 83.35%
# Epoch [5/5] | Batch #300 | Batch Accuracy 83.43%
# Epoch [5/5] | Batch #301 | Batch Accuracy 83.44%
# Epoch [5/5] | Batch #302 | Batch Accuracy 83.46%
# Epoch [5/5] | Batch #303 | Batch Accuracy 83.42%
# Epoch [5/5] | Batch #304 | Batch Accuracy 83.49%
# Epoch [5/5] | Batch #305 | Batch Accuracy 83.61%
# Epoch [5/5] Train Loss: 0.4547 | Train Acc: 83.61% | Val Acc: 68.75% | Val Loss: 0.84%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▄▃▂▁</td></tr><tr><td>validation_accuracy</td><td>▁█▄█▇</td></tr><tr><td>validation_loss</td><td>█▂▅▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.45465</td></tr><tr><td>validation_accuracy</td><td>68.75</td></tr><tr><td>validation_loss</td><td>0.8443</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">amandaaa-HappyWhale-SpeciesDataset-hyperparameters_mod2</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/borv6urb' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/borv6urb</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260302_192956-borv6urb/logs</code>
# /tmp/ipykernel_3330518/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# The overall accuracy was much higher than the previous two, so it seems like it was successful.

# %% [markdown]
# #### Your Model 3 (10 pts)

# %% [markdown]
# <font color='magenta'>Describe your changes to the model training process (either changing something about the model, a hyperparameter, how data was inputted into the model, or another aspect) and why you selected those changes.

# %% [markdown]
# I'm going to change the learning rate back to the original rate and change the optimizer from Adam to SGD to see how that impacts it.

# %%
batchsize = 48
learning_rate=1e-3
epochs=5

train_loader = DataLoader(train_set, batch_size=batchsize, drop_last=True, sampler=train_sampler)
val_loader = DataLoader(val_set, batch_size=batchsize, drop_last=True, shuffle=True)
test_loader = DataLoader(test_set, batch_size=batchsize, drop_last=True, shuffle=True)

# %%
## Model
#########
## First, we create the basic block that will be used in our residual net
class BasicBlock(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock, self).__init__()
        ## Conv1: convolution layer, batch normalization, ReLU activation
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        ## Conv2: convolution layer, batch normalization
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channels)

        ## Shortcut connection: adds input to output
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    # The forward method calls on each layer
    def forward(self, x):
        ## Conv1: convolution layer, batch normalization, ReLU activation
        out = self.conv1(x) 
        out = self.bn1(out)
        out = self.relu(out)
        ## Conv2: convolution layer, batch normalization
        out = self.conv2(out)
        out = self.bn2(out)
        ## Shortcut connection
        out += self.shortcut(x)
        ## Final activation
        out = self.relu(out)
        return out

############
## Next, we put together these building blocks and create our residual net
class ResNet18(nn.Module):
    # specify the number of classes that we are predicting
    def __init__(self, num_classes=6):
        super(ResNet18, self).__init__()
        # In channels = Num pixels in H + Num pixels in W
        self.in_channels = 64
        
        # First convolution set (convolution, batch norm, relu)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.relu = nn.ReLU(inplace=True)

        # Our building blocks
        # The numbers correspond to the matrix shape
        ### We increase the number of channels (i.e., the first number) as we go
        self.layer1 = self._make_layer(BasicBlock, 64, 2, stride=1)
        self.layer2 = self._make_layer(BasicBlock, 128, 2, stride=2)
        self.layer3 = self._make_layer(BasicBlock, 256, 2, stride=2)
        self.layer4 = self._make_layer(BasicBlock, 512, 2, stride=2)

        # Average pooling 
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

        # Final layer that makes the classification
        self.fc = nn.Linear(512, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            self.in_channels = out_channels
        return nn.Sequential(*layers)

    def forward(self, x):
        # First convolution set (convolution, batch norm, relu)
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        # Our 4 building blocks
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        # Final layer that makes the classification
        out = self.fc(out)
        return out

## Getting our model and transferring it to the GPU
model = ResNet18().to(device)

#define loss function & optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)

# %%
wandb.init(
    project="BGMP_HappyWhale",
    name="amandaaaa-HappyWhale-SpeciesDataset-hyperparameters_mod3", ##update this with your name
    config={"learning rate":.001, # possibly update
        "architecture": "CNN",
        "dataset": "Species",
        "epochs": 3, "batch_size":48}  # possibly update
) 

batch=0
num_epochs = epochs
train_losses, train_acc_list, val_losses, val_acc_list = [], [], [],[]

for epoch in range(num_epochs):
    # Setting model to "training mode"
    model.train()
    running_loss = 0.0
    correct, total = 0, 0

    # For each batch of data within the loader
    for inputs, labels in train_loader:
        # Send our input images and their labels to the GPU
        inputs, labels = inputs.to(device), labels.to(device)
        # Zero the gradients
        optimizer.zero_grad()
        # Inputting our training images into the model
        # and Predicting the image classification label
        outputs = model(inputs)
        # Figuring out the loss from our predictions
        loss = criterion(outputs, labels)
        # Compute gradients (aka backward pass)
        loss.backward()
        # Update model parameters
        optimizer.step()

        # Adding the loss to our running sum
        # Loss is calculated for each batch within an epoch
        running_loss += loss.item() * inputs.size(0)
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
        batch+=1
        print(f'Epoch [{epoch+1}/{num_epochs}] | Batch #{batch} | Batch Accuracy {(correct/total)*100:.2f}%')


    # Getting metrics for our training pass 
    train_loss = running_loss / len(train_loader.dataset)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_acc_list.append(train_acc)
    
    # Switching our model to "evaluation mode"
    model.eval()
    running_loss = 0.0
    correct, total = 0, 0
    # Disable gradient calculation b/c we are evalulating the model
    with torch.no_grad():
        # Load in batches of our validation data
        for inputs, labels in val_loader:
            # Send test images and labels to the GPU
            inputs, labels = inputs.to(device), labels.to(device)
            # Predict the image classification label
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            # Figuring out how many predicted labels = true labels
            correct += predicted.eq(labels).sum().item()

            # Figuring out the loss from our predictions
            loss = criterion(outputs, labels)
            # Adding the loss to our running sum
            # Loss is calculated for each batch within an epoch
            running_loss += loss.item() * inputs.size(0)
    # Getting our accuracy from our test data
    val_acc = 100. * correct / total
    val_acc_list.append(val_acc)
    # Getting the loss from our test data
    val_loss = running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)
    
    print(f'Epoch [{epoch+1}/{num_epochs}] Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.2f}% | Val Acc: {val_acc:.2f}% | Val Loss: {val_loss:.2f}%')

    # log metrics to wandb
    wandb.log({"validation_accuracy": val_acc, "validation_loss": val_loss, "train_loss":train_loss})

wandb.finish()

plt.plot(range(epochs), val_acc_list, color = "magenta")
plt.xlabel("Epoch number")
plt.ylabel("Valiation accuracy")
plt.show()  

plt.plot(range(epochs), val_losses, color = "purple")
plt.xlabel("Epoch number")
plt.ylabel("Valiation loss")
plt.show()  

y_pred, y_true = predict(model, test_set)
cm_analysis(y_true, y_pred, "Confusion matrix")
# Out:
# Tracking run with wandb version 0.25.0
# Run data is saved locally in <code>/gpfs/home/amdo/HappyWhaleClassifier/wandb/run-20260302_195122-ykv4csp2</code>
# Syncing run <strong><a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/ykv4csp2' target="_blank">amandaaaa-HappyWhale-SpeciesDataset-hyperparameters_mod3</a></strong> to <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a>
#  View run at <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/ykv4csp2' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/ykv4csp2</a>
# Epoch [1/5] | Batch #1 | Batch Accuracy 18.75%
# Epoch [1/5] | Batch #2 | Batch Accuracy 19.79%
# Epoch [1/5] | Batch #3 | Batch Accuracy 31.25%
# Epoch [1/5] | Batch #4 | Batch Accuracy 37.50%
# Epoch [1/5] | Batch #5 | Batch Accuracy 39.58%
# Epoch [1/5] | Batch #6 | Batch Accuracy 40.62%
# Epoch [1/5] | Batch #7 | Batch Accuracy 42.26%
# Epoch [1/5] | Batch #8 | Batch Accuracy 42.45%
# Epoch [1/5] | Batch #9 | Batch Accuracy 42.36%
# Epoch [1/5] | Batch #10 | Batch Accuracy 42.50%
# Epoch [1/5] | Batch #11 | Batch Accuracy 43.37%
# Epoch [1/5] | Batch #12 | Batch Accuracy 44.44%
# Epoch [1/5] | Batch #13 | Batch Accuracy 44.39%
# Epoch [1/5] | Batch #14 | Batch Accuracy 45.24%
# Epoch [1/5] | Batch #15 | Batch Accuracy 46.11%
# Epoch [1/5] | Batch #16 | Batch Accuracy 47.66%
# Epoch [1/5] | Batch #17 | Batch Accuracy 47.55%
# Epoch [1/5] | Batch #18 | Batch Accuracy 47.92%
# Epoch [1/5] | Batch #19 | Batch Accuracy 48.46%
# Epoch [1/5] | Batch #20 | Batch Accuracy 48.44%
# Epoch [1/5] | Batch #21 | Batch Accuracy 48.81%
# Epoch [1/5] | Batch #22 | Batch Accuracy 48.77%
# Epoch [1/5] | Batch #23 | Batch Accuracy 49.00%
# Epoch [1/5] | Batch #24 | Batch Accuracy 49.48%
# Epoch [1/5] | Batch #25 | Batch Accuracy 49.00%
# Epoch [1/5] | Batch #26 | Batch Accuracy 48.48%
# Epoch [1/5] | Batch #27 | Batch Accuracy 48.69%
# Epoch [1/5] | Batch #28 | Batch Accuracy 48.88%
# Epoch [1/5] | Batch #29 | Batch Accuracy 49.21%
# Epoch [1/5] | Batch #30 | Batch Accuracy 49.86%
# Epoch [1/5] | Batch #31 | Batch Accuracy 50.27%
# Epoch [1/5] | Batch #32 | Batch Accuracy 50.72%
# Epoch [1/5] | Batch #33 | Batch Accuracy 50.82%
# Epoch [1/5] | Batch #34 | Batch Accuracy 50.86%
# Epoch [1/5] | Batch #35 | Batch Accuracy 51.07%
# Epoch [1/5] | Batch #36 | Batch Accuracy 51.22%
# Epoch [1/5] | Batch #37 | Batch Accuracy 51.52%
# Epoch [1/5] | Batch #38 | Batch Accuracy 51.32%
# Epoch [1/5] | Batch #39 | Batch Accuracy 51.44%
# Epoch [1/5] | Batch #40 | Batch Accuracy 51.88%
# Epoch [1/5] Train Loss: 1.3094 | Train Acc: 51.88% | Val Acc: 43.23% | Val Loss: 1.37%
# Epoch [2/5] | Batch #41 | Batch Accuracy 64.58%
# Epoch [2/5] | Batch #42 | Batch Accuracy 61.46%
# Epoch [2/5] | Batch #43 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #44 | Batch Accuracy 61.98%
# Epoch [2/5] | Batch #45 | Batch Accuracy 60.83%
# Epoch [2/5] | Batch #46 | Batch Accuracy 60.07%
# Epoch [2/5] | Batch #47 | Batch Accuracy 59.82%
# Epoch [2/5] | Batch #48 | Batch Accuracy 59.90%
# Epoch [2/5] | Batch #49 | Batch Accuracy 59.72%
# Epoch [2/5] | Batch #50 | Batch Accuracy 59.17%
# Epoch [2/5] | Batch #51 | Batch Accuracy 60.98%
# Epoch [2/5] | Batch #52 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #53 | Batch Accuracy 59.62%
# Epoch [2/5] | Batch #54 | Batch Accuracy 58.78%
# Epoch [2/5] | Batch #55 | Batch Accuracy 58.75%
# Epoch [2/5] | Batch #56 | Batch Accuracy 59.64%
# Epoch [2/5] | Batch #57 | Batch Accuracy 59.68%
# Epoch [2/5] | Batch #58 | Batch Accuracy 60.53%
# Epoch [2/5] | Batch #59 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #60 | Batch Accuracy 60.31%
# Epoch [2/5] | Batch #61 | Batch Accuracy 60.12%
# Epoch [2/5] | Batch #62 | Batch Accuracy 60.32%
# Epoch [2/5] | Batch #63 | Batch Accuracy 59.87%
# Epoch [2/5] | Batch #64 | Batch Accuracy 59.90%
# Epoch [2/5] | Batch #65 | Batch Accuracy 59.33%
# Epoch [2/5] | Batch #66 | Batch Accuracy 59.21%
# Epoch [2/5] | Batch #67 | Batch Accuracy 58.87%
# Epoch [2/5] | Batch #68 | Batch Accuracy 58.85%
# Epoch [2/5] | Batch #69 | Batch Accuracy 58.48%
# Epoch [2/5] | Batch #70 | Batch Accuracy 58.68%
# Epoch [2/5] | Batch #71 | Batch Accuracy 58.74%
# Epoch [2/5] | Batch #72 | Batch Accuracy 58.85%
# Epoch [2/5] | Batch #73 | Batch Accuracy 59.09%
# Epoch [2/5] | Batch #74 | Batch Accuracy 59.38%
# Epoch [2/5] | Batch #75 | Batch Accuracy 59.70%
# Epoch [2/5] | Batch #76 | Batch Accuracy 60.07%
# Epoch [2/5] | Batch #77 | Batch Accuracy 60.30%
# Epoch [2/5] | Batch #78 | Batch Accuracy 60.47%
# Epoch [2/5] | Batch #79 | Batch Accuracy 60.42%
# Epoch [2/5] | Batch #80 | Batch Accuracy 61.15%
# Epoch [2/5] Train Loss: 1.0378 | Train Acc: 61.15% | Val Acc: 59.90% | Val Loss: 1.23%
# Epoch [3/5] | Batch #81 | Batch Accuracy 66.67%
# Epoch [3/5] | Batch #82 | Batch Accuracy 64.58%
# Epoch [3/5] | Batch #83 | Batch Accuracy 68.06%
# Epoch [3/5] | Batch #84 | Batch Accuracy 71.35%
# Epoch [3/5] | Batch #85 | Batch Accuracy 73.75%
# Epoch [3/5] | Batch #86 | Batch Accuracy 73.26%
# Epoch [3/5] | Batch #87 | Batch Accuracy 72.92%
# Epoch [3/5] | Batch #88 | Batch Accuracy 72.40%
# Epoch [3/5] | Batch #89 | Batch Accuracy 71.99%
# Epoch [3/5] | Batch #90 | Batch Accuracy 70.62%
# Epoch [3/5] | Batch #91 | Batch Accuracy 71.59%
# Epoch [3/5] | Batch #92 | Batch Accuracy 72.22%
# Epoch [3/5] | Batch #93 | Batch Accuracy 71.63%
# Epoch [3/5] | Batch #94 | Batch Accuracy 72.47%
# Epoch [3/5] | Batch #95 | Batch Accuracy 71.94%
# Epoch [3/5] | Batch #96 | Batch Accuracy 71.22%
# Epoch [3/5] | Batch #97 | Batch Accuracy 70.96%
# Epoch [3/5] | Batch #98 | Batch Accuracy 70.49%
# Epoch [3/5] | Batch #99 | Batch Accuracy 70.94%
# Epoch [3/5] | Batch #100 | Batch Accuracy 70.62%
# Epoch [3/5] | Batch #101 | Batch Accuracy 70.54%
# Epoch [3/5] | Batch #102 | Batch Accuracy 70.64%
# Epoch [3/5] | Batch #103 | Batch Accuracy 70.38%
# Epoch [3/5] | Batch #104 | Batch Accuracy 70.66%
# Epoch [3/5] | Batch #105 | Batch Accuracy 70.58%
# Epoch [3/5] | Batch #106 | Batch Accuracy 70.27%
# Epoch [3/5] | Batch #107 | Batch Accuracy 70.14%
# Epoch [3/5] | Batch #108 | Batch Accuracy 70.16%
# Epoch [3/5] | Batch #109 | Batch Accuracy 70.04%
# Epoch [3/5] | Batch #110 | Batch Accuracy 69.86%
# Epoch [3/5] | Batch #111 | Batch Accuracy 69.69%
# Epoch [3/5] | Batch #112 | Batch Accuracy 69.73%
# Epoch [3/5] | Batch #113 | Batch Accuracy 69.63%
# Epoch [3/5] | Batch #114 | Batch Accuracy 69.49%
# Epoch [3/5] | Batch #115 | Batch Accuracy 69.29%
# Epoch [3/5] | Batch #116 | Batch Accuracy 69.16%
# Epoch [3/5] | Batch #117 | Batch Accuracy 68.98%
# Epoch [3/5] | Batch #118 | Batch Accuracy 69.08%
# Epoch [3/5] | Batch #119 | Batch Accuracy 69.12%
# Epoch [3/5] | Batch #120 | Batch Accuracy 69.01%
# Epoch [3/5] Train Loss: 0.8342 | Train Acc: 69.01% | Val Acc: 55.73% | Val Loss: 1.20%
# Epoch [4/5] | Batch #121 | Batch Accuracy 62.50%
# Epoch [4/5] | Batch #122 | Batch Accuracy 63.54%
# Epoch [4/5] | Batch #123 | Batch Accuracy 65.28%
# Epoch [4/5] | Batch #124 | Batch Accuracy 66.67%
# Epoch [4/5] | Batch #125 | Batch Accuracy 65.42%
# Epoch [4/5] | Batch #126 | Batch Accuracy 64.93%
# Epoch [4/5] | Batch #127 | Batch Accuracy 64.88%
# Epoch [4/5] | Batch #128 | Batch Accuracy 65.10%
# Epoch [4/5] | Batch #129 | Batch Accuracy 65.97%
# Epoch [4/5] | Batch #130 | Batch Accuracy 66.46%
# Epoch [4/5] | Batch #131 | Batch Accuracy 67.23%
# Epoch [4/5] | Batch #132 | Batch Accuracy 67.36%
# Epoch [4/5] | Batch #133 | Batch Accuracy 67.95%
# Epoch [4/5] | Batch #134 | Batch Accuracy 68.45%
# Epoch [4/5] | Batch #135 | Batch Accuracy 68.47%
# Epoch [4/5] | Batch #136 | Batch Accuracy 67.97%
# Epoch [4/5] | Batch #137 | Batch Accuracy 68.50%
# Epoch [4/5] | Batch #138 | Batch Accuracy 68.63%
# Epoch [4/5] | Batch #139 | Batch Accuracy 68.31%
# Epoch [4/5] | Batch #140 | Batch Accuracy 68.12%
# Epoch [4/5] | Batch #141 | Batch Accuracy 68.15%
# Epoch [4/5] | Batch #142 | Batch Accuracy 67.99%
# Epoch [4/5] | Batch #143 | Batch Accuracy 67.93%
# Epoch [4/5] | Batch #144 | Batch Accuracy 68.06%
# Epoch [4/5] | Batch #145 | Batch Accuracy 67.75%
# Epoch [4/5] | Batch #146 | Batch Accuracy 67.95%
# Epoch [4/5] | Batch #147 | Batch Accuracy 68.06%
# Epoch [4/5] | Batch #148 | Batch Accuracy 67.93%
# Epoch [4/5] | Batch #149 | Batch Accuracy 68.18%
# Epoch [4/5] | Batch #150 | Batch Accuracy 68.06%
# Epoch [4/5] | Batch #151 | Batch Accuracy 67.74%
# Epoch [4/5] | Batch #152 | Batch Accuracy 67.58%
# Epoch [4/5] | Batch #153 | Batch Accuracy 67.80%
# Epoch [4/5] | Batch #154 | Batch Accuracy 67.83%
# Epoch [4/5] | Batch #155 | Batch Accuracy 67.98%
# Epoch [4/5] | Batch #156 | Batch Accuracy 68.11%
# Epoch [4/5] | Batch #157 | Batch Accuracy 68.13%
# Epoch [4/5] | Batch #158 | Batch Accuracy 68.04%
# Epoch [4/5] | Batch #159 | Batch Accuracy 68.06%
# Epoch [4/5] | Batch #160 | Batch Accuracy 68.28%
# Epoch [4/5] Train Loss: 0.8196 | Train Acc: 68.28% | Val Acc: 58.59% | Val Loss: 0.94%
# Epoch [5/5] | Batch #161 | Batch Accuracy 70.83%
# Epoch [5/5] | Batch #162 | Batch Accuracy 69.79%
# Epoch [5/5] | Batch #163 | Batch Accuracy 70.83%
# Epoch [5/5] | Batch #164 | Batch Accuracy 71.88%
# Epoch [5/5] | Batch #165 | Batch Accuracy 74.17%
# Epoch [5/5] | Batch #166 | Batch Accuracy 73.61%
# Epoch [5/5] | Batch #167 | Batch Accuracy 73.51%
# Epoch [5/5] | Batch #168 | Batch Accuracy 73.96%
# Epoch [5/5] | Batch #169 | Batch Accuracy 75.23%
# Epoch [5/5] | Batch #170 | Batch Accuracy 75.42%
# Epoch [5/5] | Batch #171 | Batch Accuracy 75.19%
# Epoch [5/5] | Batch #172 | Batch Accuracy 74.48%
# Epoch [5/5] | Batch #173 | Batch Accuracy 72.92%
# Epoch [5/5] | Batch #174 | Batch Accuracy 73.66%
# Epoch [5/5] | Batch #175 | Batch Accuracy 73.47%
# Epoch [5/5] | Batch #176 | Batch Accuracy 73.05%
# Epoch [5/5] | Batch #177 | Batch Accuracy 72.79%
# Epoch [5/5] | Batch #178 | Batch Accuracy 72.45%
# Epoch [5/5] | Batch #179 | Batch Accuracy 73.03%
# Epoch [5/5] | Batch #180 | Batch Accuracy 73.33%
# Epoch [5/5] | Batch #181 | Batch Accuracy 73.31%
# Epoch [5/5] | Batch #182 | Batch Accuracy 73.77%
# Epoch [5/5] | Batch #183 | Batch Accuracy 74.28%
# Epoch [5/5] | Batch #184 | Batch Accuracy 73.96%
# Epoch [5/5] | Batch #185 | Batch Accuracy 74.25%
# Epoch [5/5] | Batch #186 | Batch Accuracy 74.36%
# Epoch [5/5] | Batch #187 | Batch Accuracy 74.23%
# Epoch [5/5] | Batch #188 | Batch Accuracy 74.33%
# Epoch [5/5] | Batch #189 | Batch Accuracy 74.21%
# Epoch [5/5] | Batch #190 | Batch Accuracy 73.75%
# Epoch [5/5] | Batch #191 | Batch Accuracy 73.12%
# Epoch [5/5] | Batch #192 | Batch Accuracy 73.37%
# Epoch [5/5] | Batch #193 | Batch Accuracy 73.04%
# Epoch [5/5] | Batch #194 | Batch Accuracy 73.04%
# Epoch [5/5] | Batch #195 | Batch Accuracy 72.86%
# Epoch [5/5] | Batch #196 | Batch Accuracy 72.80%
# Epoch [5/5] | Batch #197 | Batch Accuracy 72.92%
# Epoch [5/5] | Batch #198 | Batch Accuracy 72.97%
# Epoch [5/5] | Batch #199 | Batch Accuracy 73.13%
# Epoch [5/5] | Batch #200 | Batch Accuracy 72.81%
# Epoch [5/5] Train Loss: 0.7382 | Train Acc: 72.81% | Val Acc: 50.52% | Val Loss: 2.38%
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>█▅▂▂▁</td></tr><tr><td>validation_accuracy</td><td>▁█▆▇▄</td></tr><tr><td>validation_loss</td><td>▃▂▂▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train_loss</td><td>0.73825</td></tr><tr><td>validation_accuracy</td><td>50.52083</td></tr><tr><td>validation_loss</td><td>2.38134</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">amandaaaa-HappyWhale-SpeciesDataset-hyperparameters_mod3</strong> at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/ykv4csp2' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale/runs/ykv4csp2</a><br> View project at: <a href='https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale' target="_blank">https://wandb.ai/BGMP_HappyWhale/BGMP_HappyWhale</a><br>Synced 7 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260302_195122-ykv4csp2/logs</code>
# /tmp/ipykernel_3330518/2764316866.py:50: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)

# %% [markdown]
# <font color='magenta'>Were your changes successful? Do you have ideas why your changes were successful or not?

# %% [markdown]
# Definitely not! The accuracy improvement for this model was nonexistent and even though the accuracy improved throughout the epochs, overall the other two were more successful (i think).
# train_loss	0.73825
# validation_accuracy	50.52083
# validation_loss	2.38134

# %% [markdown]
# <font color='magenta'>Summarize your 3 steps, their success, and what you learned (5 pts)

# %% [markdown]
# The first round, I changed the learning rate: LR = 3e-4; the second round, I changed the batch size, learning rate, and added weights, and the third round I used the SGD optimizer. Overall, the first change was by far the most successful, suggesting that the model was most sensitive to changes in learning rate. Adjusting the learning rate alone (3e-4) produced the largest performance improvement, so it seems like the hyperparameter tuning is more important at times than batch size, class weighting, or optimizer choice.

# %% [markdown]
# *Your answer here*
